# %%
import pandas as pd

# %%
df = pd.read_csv('final.csv')

# %%
test = df.copy()

# %%
test
# Out:
#      Unnamed: 0  YEAR  MONTH      DISTRICT landslide_size  fatality_count  \
# 0             0  2009      7       Dailekh         medium             1.0
# 1             1  2009      7         Kaski         medium             3.0
# 2             2  2009      7     Kathmandu          large            13.0
# 3             3  2009      7       Syangja         medium             5.0
# 4             4  2011      7  Arghakhanchi         medium             2.0
# ..          ...   ...    ...           ...            ...             ...
# 253         253  2018     12        Rasuwa          small             0.0
# 254         254  2018     12        Rasuwa          small             0.0
# 255         255  2018      9       Nuwakot        unknown             0.0
# 256         256  2018      9       Lamjung          large             2.0
# 257         257  2018      9       Lamjung          large             2.0
#
#      injury_count   latitude  longitude  PRECTOT  ...  T2M_RANGE     TS  \
# ...

# %%
test['output'] = [1 for i in range(258)]

# %%
test.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
test
# Out:
#      YEAR  MONTH      DISTRICT landslide_size  fatality_count  injury_count  \
# 0    2009      7       Dailekh         medium             1.0           0.0
# 1    2009      7         Kaski         medium             3.0           0.0
# 2    2009      7     Kathmandu          large            13.0           0.0
# 3    2009      7       Syangja         medium             5.0           0.0
# 4    2011      7  Arghakhanchi         medium             2.0           0.0
# ..    ...    ...           ...            ...             ...           ...
# 253  2018     12        Rasuwa          small             0.0           0.0
# 254  2018     12        Rasuwa          small             0.0           0.0
# 255  2018      9       Nuwakot        unknown             0.0           0.0
# 256  2018      9       Lamjung          large             2.0           0.0
# 257  2018      9       Lamjung          large             2.0           0.0
#
# ...

# %%
climate = pd.read_csv('climate_data_nepal_district_wise_monthly.csv')

# %%
import random
rand = []
for i in range(258):
    rand.append(random.randint(1000, 29013))

# %%
climate['index'] = climate.index

# %%
climate
# Out:
#              DATE  YEAR  MONTH      DISTRICT   LAT   LON  PRECTOT     PS  \
# 0      1981-01-31  1981      1  Arghakhanchi  27.9  83.2    67.31  93.78
# 1      1981-02-28  1981      2  Arghakhanchi  27.9  83.2     3.37  93.52
# 2      1981-03-31  1981      3  Arghakhanchi  27.9  83.2    26.02  93.40
# 3      1981-04-30  1981      4  Arghakhanchi  27.9  83.2    46.15  93.03
# 4      1981-05-31  1981      5  Arghakhanchi  27.9  83.2    69.45  92.75
# ...           ...   ...    ...           ...   ...   ...      ...    ...
# 29011  2019-08-31  2019      8      Udayapur  26.9  86.5     4.46  94.41
# 29012  2019-09-30  2019      9      Udayapur  26.9  86.5     9.93  94.92
# 29013  2019-10-31  2019     10      Udayapur  26.9  86.5     0.28  95.34
# 29014  2019-11-30  2019     11      Udayapur  26.9  86.5     0.04  95.48
# 29015  2019-12-31  2019     12      Udayapur  26.9  86.5     0.35  95.74
#
#         QV2M   RH2M  ...     TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  \
# ...

# %%
climate[climate['index'].isin(rand)]
# Out:
#              DATE  YEAR  MONTH      DISTRICT   LAT   LON  PRECTOT     PS  \
# index
# 58     1985-11-30  1985     11  Arghakhanchi  27.9  83.2     0.00  93.59
#
# ...

# %%
climate.drop(['index'], axis=1, inplace=True)

# %%
climate.index = [i for i in range(257)]

# %%
climate.drop(['DATE'], axis=1, inplace = True)

# %%
climate
# Out:
#      YEAR  MONTH   DISTRICT   LAT   LON  PRECTOT     PS   QV2M   RH2M    T2M  \
# 0    1997      4    Baitadi  29.5  80.5    45.04  73.91   4.82  49.94   9.16
# 1    2000     10    Baitadi  29.5  80.5     0.02  74.01   5.29  48.03  10.68
# 2    2003     11    Baitadi  29.5  80.5     0.81  74.11   3.40  41.89   6.21
# 3    2009     12    Baitadi  29.5  80.5     1.62  73.95   2.84  44.55   2.82
# 4    1981     12     Bajang  29.6  81.2     7.64  67.98   1.77  40.92  -3.47
# ..    ...    ...        ...   ...   ...      ...    ...    ...    ...    ...
# 252  2017     11  Terhathum  27.1  87.5     1.37  80.29   7.87  75.20  11.19
# 253  1983      1   Udayapur  26.9  86.5     0.15  95.70   3.35  31.58  14.37
# 254  1991     10   Udayapur  26.9  86.5     1.15  95.14  12.08  63.81  23.18
# 255  2006      9   Udayapur  26.9  86.5   328.17  94.84  17.63  83.90  25.03
# 256  2013     12   Udayapur  26.9  86.5     0.22  95.50   7.13  61.65  15.47
#
# ...

# %%
#check if false label generated has common data with true label
match = []
cm = climate['MONTH']
tm = climate['MONTH']
cp = climate["PRECTOT"]
tp = test["PRECTOT"]
for i in tp.index:
    for j in cp.index:
        if tp[i] == cp[j] and tm[i] == cm[j]:
            match.append(cp[j])

# %%
match
# Out:
# []

# %%
climate
# Out:
#      YEAR  MONTH   DISTRICT   LAT   LON  PRECTOT     PS   QV2M   RH2M    T2M  \
# 0    1997      4    Baitadi  29.5  80.5    45.04  73.91   4.82  49.94   9.16
# 1    2000     10    Baitadi  29.5  80.5     0.02  74.01   5.29  48.03  10.68
# 2    2003     11    Baitadi  29.5  80.5     0.81  74.11   3.40  41.89   6.21
# 3    2009     12    Baitadi  29.5  80.5     1.62  73.95   2.84  44.55   2.82
# 4    1981     12     Bajang  29.6  81.2     7.64  67.98   1.77  40.92  -3.47
# ..    ...    ...        ...   ...   ...      ...    ...    ...    ...    ...
# 252  2017     11  Terhathum  27.1  87.5     1.37  80.29   7.87  75.20  11.19
# 253  1983      1   Udayapur  26.9  86.5     0.15  95.70   3.35  31.58  14.37
# 254  1991     10   Udayapur  26.9  86.5     1.15  95.14  12.08  63.81  23.18
# 255  2006      9   Udayapur  26.9  86.5   328.17  94.84  17.63  83.90  25.03
# 256  2013     12   Udayapur  26.9  86.5     0.22  95.50   7.13  61.65  15.47
#
# ...

# %%
climate['output'] = [0 for i in range(257)]

# %%
climate
# Out:
#      YEAR  MONTH   DISTRICT   LAT   LON  PRECTOT     PS   QV2M   RH2M    T2M  \
# 0    1989     12    Baitadi  29.5  80.5     4.69  74.05   2.05  34.48   2.63
# 1    1994      1    Baitadi  29.5  80.5    13.26  73.87   2.48  42.45   2.03
# 2    2009      3    Baitadi  29.5  80.5     2.63  73.91   3.25  38.17   7.09
# 3    2009      4    Baitadi  29.5  80.5     5.05  73.89   3.77  31.64  12.41
# 4    2010     11    Baitadi  29.5  80.5    31.64  74.07   5.07  61.62   6.48
# ..    ...    ...        ...   ...   ...      ...    ...    ...    ...    ...
# 251  2016      1  Terhathum  27.1  87.5     6.69  80.17   4.15  57.71   5.86
# 252  2016      8  Terhathum  27.1  87.5   152.16  79.77  15.70  90.32  19.07
# 253  2016     12  Terhathum  27.1  87.5     0.11  80.30   6.08  64.45   9.81
# 254  2000      6   Udayapur  26.9  86.5   137.51  94.30  17.11  65.54  28.78
# 255  2015      2   Udayapur  26.9  86.5     3.39  95.47   5.76  39.51  19.04
#
# ...

# %%
climate['landslide_size'] = ['no' for i in range(257)]
climate['fatality_count'] = [0 for i in range(257)]
climate['injury_count'] = [0 for i in range(257)]

# %%
climate
# Out:
#      YEAR  MONTH   DISTRICT   LAT   LON  PRECTOT     PS   QV2M   RH2M    T2M  \
# 0    1997      4    Baitadi  29.5  80.5    45.04  73.91   4.82  49.94   9.16
# 1    2000     10    Baitadi  29.5  80.5     0.02  74.01   5.29  48.03  10.68
# 2    2003     11    Baitadi  29.5  80.5     0.81  74.11   3.40  41.89   6.21
# 3    2009     12    Baitadi  29.5  80.5     1.62  73.95   2.84  44.55   2.82
# 4    1981     12     Bajang  29.6  81.2     7.64  67.98   1.77  40.92  -3.47
# ..    ...    ...        ...   ...   ...      ...    ...    ...    ...    ...
# 252  2017     11  Terhathum  27.1  87.5     1.37  80.29   7.87  75.20  11.19
# 253  1983      1   Udayapur  26.9  86.5     0.15  95.70   3.35  31.58  14.37
# 254  1991     10   Udayapur  26.9  86.5     1.15  95.14  12.08  63.81  23.18
# 255  2006      9   Udayapur  26.9  86.5   328.17  94.84  17.63  83.90  25.03
# 256  2013     12   Udayapur  26.9  86.5     0.22  95.50   7.13  61.65  15.47
#
# ...

# %%
climate = climate.reindex(columns=['YEAR', 'MONTH', 'DISTRICT', 'landslide_size', 'fatality_count',
       'injury_count', 'LAT', 'LON', 'PRECTOT', 'PS', 'QV2M',
       'RH2M', 'T2M', 'T2MWET', 'T2M_MAX', 'T2M_MIN', 'T2M_RANGE', 'TS',
       'WS10M', 'WS10M_MAX', 'WS10M_MIN', 'WS10M_RANGE', 'WS50M', 'WS50M_MAX',
       'WS50M_MIN', 'WS50M_RANGE', 'output'])

# %%
climate.rename(columns={'LAT': 'latitude', 'LON': 'longitude'}, inplace=True)

# %%
climate
# Out:
#      YEAR  MONTH   DISTRICT landslide_size  fatality_count  injury_count  \
# 0    1997      4    Baitadi             no               0             0
# 1    2000     10    Baitadi             no               0             0
# 2    2003     11    Baitadi             no               0             0
# 3    2009     12    Baitadi             no               0             0
# 4    1981     12     Bajang             no               0             0
# ..    ...    ...        ...            ...             ...           ...
# 252  2017     11  Terhathum             no               0             0
# 253  1983      1   Udayapur             no               0             0
# 254  1991     10   Udayapur             no               0             0
# 255  2006      9   Udayapur             no               0             0
# 256  2013     12   Udayapur             no               0             0
#
#      latitude  longitude  PRECTOT     PS  ...     TS  WS10M  WS10M_MAX  \
# ...

# %%
test
# Out:
#      YEAR  MONTH      DISTRICT landslide_size  fatality_count  injury_count  \
# 0    2009      7       Dailekh         medium             1.0           0.0
# 1    2009      7         Kaski         medium             3.0           0.0
# 2    2009      7     Kathmandu          large            13.0           0.0
# 3    2009      7       Syangja         medium             5.0           0.0
# 4    2011      7  Arghakhanchi         medium             2.0           0.0
# ..    ...    ...           ...            ...             ...           ...
# 253  2018     12        Rasuwa          small             0.0           0.0
# 254  2018     12        Rasuwa          small             0.0           0.0
# 255  2018      9       Nuwakot        unknown             0.0           0.0
# 256  2018      9       Lamjung          large             2.0           0.0
# 257  2018      9       Lamjung          large             2.0           0.0
#
# ...

# %%
new = test.append(climate)

# %%
new
# Out:
#      YEAR  MONTH      DISTRICT landslide_size  fatality_count  injury_count  \
# 0    2009      7       Dailekh         medium             1.0           0.0
# 1    2009      7         Kaski         medium             3.0           0.0
# 2    2009      7     Kathmandu          large            13.0           0.0
# 3    2009      7       Syangja         medium             5.0           0.0
# 4    2011      7  Arghakhanchi         medium             2.0           0.0
# ..    ...    ...           ...            ...             ...           ...
# 252  2017     11     Terhathum             no             0.0           0.0
# 253  1983      1      Udayapur             no             0.0           0.0
# 254  1991     10      Udayapur             no             0.0           0.0
# 255  2006      9      Udayapur             no             0.0           0.0
# 256  2013     12      Udayapur             no             0.0           0.0
#
# ...

# %%
new.reset_index(drop=True)
# Out:
#      YEAR  MONTH      DISTRICT landslide_size  fatality_count  injury_count  \
# 0    2009      7       Dailekh         medium             1.0           0.0
# 1    2009      7         Kaski         medium             3.0           0.0
# 2    2009      7     Kathmandu          large            13.0           0.0
# 3    2009      7       Syangja         medium             5.0           0.0
# 4    2011      7  Arghakhanchi         medium             2.0           0.0
# ..    ...    ...           ...            ...             ...           ...
# 510  2017     11     Terhathum             no             0.0           0.0
# 511  1983      1      Udayapur             no             0.0           0.0
# 512  1991     10      Udayapur             no             0.0           0.0
# 513  2006      9      Udayapur             no             0.0           0.0
# 514  2013     12      Udayapur             no             0.0           0.0
#
# ...

# %%
new = new.sample(frac=1).reset_index(drop=True)

# %%
new
# Out:
#      YEAR  MONTH    DISTRICT landslide_size  fatality_count  injury_count  \
# 0    2013      7     Syangja         medium             1.0           0.0
# 1    2017      6       Kaski         medium             0.0           1.0
# 2    2004      6      Salyan             no             0.0           0.0
# 3    2015      8   Kathmandu         medium             1.0           0.0
# 4    2017      3     Baglung          large             1.0           0.0
# ..    ...    ...         ...            ...             ...           ...
# 510  2018      7     Bardiya             no             0.0           0.0
# 511  2013      7  Solukhumbu         medium             0.0           0.0
# 512  1990      4     Dhanusa             no             0.0           0.0
# 513  2007      8       Gulmi         medium             3.0           0.0
# 514  2009      8  Dadeldhura         medium             1.0           0.0
#
#       latitude  longitude  PRECTOT     PS  ...     TS  WS10M  WS10M_MAX  \
# ...

# %%
new.to_csv('landslide_nepal.csv')
